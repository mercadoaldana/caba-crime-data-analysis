# %% [markdown]
# # Crime Analysis

# %% [markdown]
# ## Introduction
# The objective of this notebook is to produce an interactive map showing the crimes that ocurred in the Ciudad Autónoma de Buenos Aires (C.A.B.A) between the years 2016 and 2021.

# %%
# Needed libraries
import pandas as pd

# %%
df_2016 = pd.read_csv('data/delitos_2016.csv')

# %%
df_2016
# Out:
#             id       fecha franja_horaria            tipo_delito  \
# 0        51585  2016-01-01             13   Robo (con violencia)
# 1        83256  2016-01-01             22   Robo (con violencia)
# 2       117697  2016-01-01              1               Lesiones
# 3        43088  2016-01-01             19  Hurto (sin violencia)
# 4        68588  2016-01-01              4   Robo (con violencia)
# ...        ...         ...            ...                    ...
# 126578   81281  2016-12-31              0   Robo (con violencia)
# 126579   95847  2016-12-31              2   Robo (con violencia)
# 126580   79693  2016-12-31              6   Robo (con violencia)
# 126581   81292  2016-12-31             11   Robo (con violencia)
# 126582   81314  2016-12-31             18   Robo (con violencia)
#
#         subtipo_delito  cantidad_registrada  comuna             barrio  \
# 0                  NaN                  1.0     9.0  Parque Avellaneda
# ...
